# %% [markdown]
# # pandas - "A melhor biblioteca do Python para Dados"
#
# - Quase sempre que você for trabalhar com dados no Python você vai usar o pandas, então é importante você saber trabalhar com essa biblioteca muito bem
#
# - Vamos aprender os principais comandos e os princípios básicos do pandas
#
# - Faça o download do Gabarito desse arquivo e use como uma cartilha de consulta (Link na descrição)

# %% [markdown]
# ### Importando o pandas

# %%
import pandas as pd

# %% [markdown]
# ### Criando um dataframe a partir de um dicionário

# %%
# dataframe = pd.DataFrame()
venda = {'data': ['15/02/2021', '16/02/2021'],
         'valor': [500, 300],
         'produto': ['feijao', 'arroz'],
         'qtde': [50, 70],
        }
vendas_df = pd.DataFrame(venda)

# %% [markdown]
# ### Visualização dos Dados
#     - print
#     - display

# %%
display(vendas_df)
# Out:
#          data  valor produto  qtde
# 0  15/02/2021    500  feijao    50
# 1  16/02/2021    300   arroz    70

# %% [markdown]
# ### Importando arquivos e bases de dados

# %%
vendas_df = pd.read_excel("Vendas.xlsx")
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# 1               2             180          360
# 2               1             368          368
# 3               3             200          600
# 4               1              71           71
# ...           ...             ...          ...
# 93905           2             283          566
# 93906           2              79          158
# 93907           3              67          201
# 93908           5             114          570
# 93909           4             259         1036
#
# [93910 rows x 7 columns]

# %% [markdown]
# ### Resumos de Visualização de Dados simples e úteis
#     - head
#     - shape
#     - describe

# %%
display(vendas_df.head(10))
display(vendas_df.shape)
display(vendas_df.describe())
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final
# 0          Sapato Estampa           1             358          358
# 1                Camiseta           2             180          360
# 2           Sapato Xadrez           1             368          368
# 3                 Relógio           3             200          600
# 4            Chinelo Liso           1              71           71
# 5             Cinto Linho           1             248          248
# 6                   Calça           1             170          170
# 7           Polo Listrado           4             149          596
# 8  Camisa Gola V Listrado           1             116          116
# 9             Camisa Liso           1             105          105
# (93910, 7)
#        Código Venda    Quantidade  Valor Unitário   Valor Final
# count  93910.000000  93910.000000    93910.000000  93910.000000
# mean   32464.762155      2.166553      191.725886    414.862656
# std    18809.007093      1.258732      145.215519    434.846228
# min        1.000000      1.000000       30.000000     30.000000
# 25%    16204.000000      1.000000      100.000000    156.000000
# 50%    32367.000000      2.000000      155.000000    274.000000
# 75%    48793.750000      3.000000      248.000000    524.000000
# max    65014.000000      5.000000      750.000000   3750.000000

# %% [markdown]
# ### Pegar 1 coluna (e os pd.Series)

# %%
produtos = vendas_df['Produto']
display(produtos)
# Out:
# 0           Sapato Estampa
# 1                 Camiseta
# 2            Sapato Xadrez
# 3                  Relógio
# 4             Chinelo Liso
#                ...
# 93905       Mochila Xadrez
# 93906    Pulseira Listrado
# 93907       Cueca Listrado
# 93908       Pulseira Linho
# 93909        Casaco Xadrez
# Name: Produto, Length: 93910, dtype: object

# %% [markdown]
# ### .loc, um método muito importante
#     - Pegar 1 linha
#     - Pegar linhas de acordo com alguma condição
#     - Pegar linhas e colunas específicas
#     - Pegar 1 valor específico

# %%
# pegar uma linha
display(vendas_df.loc[1:5])

# pegar linhas que correspondem a uma condição
vendas_norteshopping_df = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping']

# pegar várias linhas e colunas usando o loc
vendas_norteshopping_df = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping', ["ID Loja", "Produto", "Quantidade"]]
display(vendas_norteshopping_df)

# pegar 1 valor específico
print(vendas_df.loc[1, 'Produto'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3620\2587949924.py in <module>
#       1 # pegar uma linha
# ----> 2 display(vendas_df.loc[1:5])
#       3
#       4 # pegar linhas que correspondem a uma condição
#       5 vendas_norteshopping_df = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1181         if isinstance(key, slice):
#    1182             self._validate_key(key, axis)
# -> 1183             return self._get_slice_axis(key, axis=axis)
#    1184         elif com.is_bool_indexer(key):
#    1185             return self._getbool_axis(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1215
#    1216         labels = obj._get_axis(axis)
# -> 1217         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1218
#    1219         if isinstance(indexer, slice):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    6286         self._deprecated_arg(kind, "kind", "slice_indexer")
#    6287
# -> 6288         start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6289
#    6290         # return a slice
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    6496         start_slice = None
#    6497         if start is not None:
# -> 6498             start_slice = self.get_slice_bound(start, "left")
#    6499         if start_slice is None:
#    6500             start_slice = 0
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    6423             slc = lib.maybe_booleans_to_slice(slc.view("u1"))
#    6424             if isinstance(slc, np.ndarray):
# -> 6425                 raise KeyError(
#    6426                     f"Cannot get {side} slice bound for non-unique "
#    6427                     f"label: {repr(original_label)}"
#
# KeyError: 'Cannot get left slice bound for non-unique label: 1'

# %% [markdown]
# ### Adicionar 1 coluna

# %%
# a partir de uma coluna que existe
vendas_df['Comissão'] = vendas_df['Valor Final'] * 0.05
#display(vendas_df)

# criar uma coluna com valor padrão
vendas_df.loc[:, "Imposto"] = 0
display(vendas_df)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 1                1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                2 2019-01-02              Norte Shopping           Relógio
# 4                2 2019-01-02              Norte Shopping      Chinelo Liso
# 5                3 2019-01-02  Rio Mar Shopping Fortaleza       Cinto Linho
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final  Comissão  Imposto
# 1              2             180          360     18.00        0
# 2              1             368          368     18.40        0
# 3              3             200          600     30.00        0
# 4              1              71           71      3.55        0
# 5              1             248          248     12.40        0
# ...          ...             ...          ...       ...      ...
# 7084           2             102          204     10.20        0
# 7085           4             270         1080     54.00        0
# 7086           1              87           87      4.35        0
# 7087           1             108          108      5.40        0
# 7088           2             133          266     13.30        0
#
# [122262 rows x 9 columns]

# %% [markdown]
# ### Adicionar 1 linha
#     - Linhas de um complemento da base de dados

# %%
vendas_dez_df = pd.read_excel("Vendas - Dez.xlsx")
#display(vendas_dez_df)

vendas_df = pd.concat([vendas_df, vendas_dez_df])
display(vendas_df)
# Out:
#       Código Venda       Data                     ID Loja  \
# 0                1 2019-01-01          Iguatemi Esplanada
# 1                1 2019-01-01          Iguatemi Esplanada
# 2               21 2019-01-02          Iguatemi Esplanada
# 3               34 2019-01-02          Iguatemi Esplanada
# 4               34 2019-01-02          Iguatemi Esplanada
# ...            ...        ...                         ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia
# 7085         69996 2019-12-26  Center Shopping Uberlândia
# 7086         69996 2019-12-26  Center Shopping Uberlândia
# 7087         69997 2019-12-26           Ribeirão Shopping
# 7088         69997 2019-12-26           Ribeirão Shopping
#
#                      Produto  Quantidade  Valor Unitário  Valor Final  \
# 0                   Camiseta           2             180          360
# 1              Sapato Xadrez           1             368          368
# 2     Camisa Gola V Listrado           2             116          232
# 3            Sapato Listrado           1             363          363
# 4         Camisa Gola V Liso           2             118          236
# ...                      ...         ...             ...          ...
# 7084          Short Listrado           2             102          204
# 7085                 Mochila           4             270         1080
# 7086        Pulseira Estampa           1              87           87
# 7087         Camisa Listrado           1             108          108
# 7088             Short Linho           2             133          266
#
#       Comissão  Imposto   Gerente
# 0        18.00      0.0  Salvador
# 1        18.40      0.0  Salvador
# 2        11.60      0.0  Salvador
# 3        18.15      0.0  Salvador
# 4        11.80      0.0  Salvador
# ...        ...      ...       ...
# 7084       NaN      NaN       NaN
# 7085       NaN      NaN       NaN
# 7086       NaN      NaN       NaN
# 7087       NaN      NaN       NaN
# 7088       NaN      NaN       NaN
#
# [129350 rows x 10 columns]

# %% [markdown]
# ### Excluir linhas e colunas

# %%
vendas_df = vendas_df.drop(0, axis=0)
display(vendas_df)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 1                1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                2 2019-01-02              Norte Shopping           Relógio
# 4                2 2019-01-02              Norte Shopping      Chinelo Liso
# 5                3 2019-01-02  Rio Mar Shopping Fortaleza       Cinto Linho
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final  Comissão  Imposto
# 1              2             180          360     18.00        0
# 2              1             368          368     18.40        0
# 3              3             200          600     30.00        0
# 4              1              71           71      3.55        0
# 5              1             248          248     12.40        0
# ...          ...             ...          ...       ...      ...
# 7084           2             102          204     10.20        0
# 7085           4             270         1080     54.00        0
# 7086           1              87           87      4.35        0
# 7087           1             108          108      5.40        0
# 7088           2             133          266     13.30        0
#
# [122261 rows x 9 columns]

# %% [markdown]
# ### Valores Vazios
#     - Deletar linhas/colunas vazias
#     - Deletar linhas que possuem valores vazios
#     - Preencher valores vazios (média e último valor)

# %%
# deletar linhas e colunas completamente vazias
# vendas_df = vendas_df.dropna(how='all', axis=1)

# deletar linhas que possuem pelo menos 1 valor vazio
#vendas_df = vendas_df.dropna()

# preencher valores vazios
# preencher com a média da coluna
vendas_df['Comissão'] = vendas_df['Comissão'].fillna(vendas_df['Comissão'].mean())
display(vendas_df)

# preencher com o último valor
vendas_df = vendas_df.ffill()
# Out:
#         Código Venda       Data             ID Loja                 Produto  \
# 0                  1 2019-01-01  Iguatemi Esplanada                Camiseta
# 1                  1 2019-01-01  Iguatemi Esplanada           Sapato Xadrez
# 2                 21 2019-01-02  Iguatemi Esplanada  Camisa Gola V Listrado
# 3                 34 2019-01-02  Iguatemi Esplanada         Sapato Listrado
# 4                 34 2019-01-02  Iguatemi Esplanada      Camisa Gola V Liso
# ...              ...        ...                 ...                     ...
# 122256         69846 2019-12-25   Salvador Shopping           Short Estampa
# 122257         69846 2019-12-25   Salvador Shopping           Tênis Estampa
# 122258         69850 2019-12-25   Salvador Shopping           Calça Estampa
# 122259         69972 2019-12-26   Salvador Shopping              Terno Liso
# 122260         69972 2019-12-26   Salvador Shopping          Sapato Estampa
#
#         Quantidade  Valor Unitário  Valor Final  Comissão  Imposto   Gerente
# 0                2             180          360     18.00        0  Salvador
# 1                1             368          368     18.40        0  Salvador
# 2                2             116          232     11.60        0  Salvador
# 3                1             363          363     18.15        0  Salvador
# 4                2             118          236     11.80        0  Salvador
# ...            ...             ...          ...       ...      ...       ...
# 122256           2              96          192      9.60        0    Mateus
# 122257           5             256         1280     64.00        0    Mateus
# 122258           4             177          708     35.40        0    Mateus
# 122259           3             720         2160    108.00        0    Mateus
# 122260           5             358         1790     89.50        0    Mateus
#
# [122261 rows x 10 columns]

# %% [markdown]
# ### Calcular Indicadores
#     - Groupby
#     - Value Counts

# %%
# value counts
transacoes_loja = vendas_df['ID Loja'].value_counts()
display(transacoes_loja)

# group by
faturamento_produto = vendas_df[['Produto', 'Valor Final']].groupby('Produto').sum()
display(faturamento_produto)
# Out:
# Rio Mar Recife                      5197
# Shopping Vila Velha                 5131
# Palladium Shopping Curitiba         5113
# Iguatemi Campinas                   5053
# Rio Mar Shopping Fortaleza          5000
# Bourbon Shopping SP                 4974
# Norte Shopping                      4944
# Salvador Shopping                   4936
# Shopping Eldorado                   4914
# Center Shopping Uberlândia          4913
# Shopping SP Market                  4896
# Shopping Iguatemi Fortaleza         4891
# Ribeirão Shopping                   4879
# Shopping Morumbi                    4874
# Shopping Ibirapuera                 4870
# Passei das Águas Shopping           4867
# Shopping União de Osasco            4847
# Shopping Center Leste Aricanduva    4783
# Shopping Center Interlagos          4783
# Parque Dom Pedro Shopping           4772
# Novo Shopping Ribeirão Preto        4766
# Iguatemi Esplanada                  4753
# Shopping Recife                     4749
# Shopping Barra                      4742
# Shopping Midway Mall                4614
# Name: ID Loja, dtype: int64
#                   Valor Final
# Produto
# Bermuda                327600
# Bermuda Estampa        347464
# Bermuda Linho          471315
# Bermuda Liso           331741
# Bermuda Listrado       353873
# ...                       ...
# Tênis Estampa          553728
# Tênis Linho            643566
# Tênis Liso             576688
# Tênis Listrado         558846
# Tênis Xadrez           548303
#
# [120 rows x 1 columns]

# %% [markdown]
# ### Mesclar 2 dataframes (Procurar informações de um dataframe em outro)

# %%
gerentes_df = pd.read_excel("Gerentes.xlsx")
#display(gerentes_df)

vendas_df = vendas_df.merge(gerentes_df)
display(vendas_df)
# Out:
#         Código Venda       Data             ID Loja                 Produto  \
# 0                  1 2019-01-01  Iguatemi Esplanada                Camiseta
# 1                  1 2019-01-01  Iguatemi Esplanada           Sapato Xadrez
# 2                 21 2019-01-02  Iguatemi Esplanada  Camisa Gola V Listrado
# 3                 34 2019-01-02  Iguatemi Esplanada         Sapato Listrado
# 4                 34 2019-01-02  Iguatemi Esplanada      Camisa Gola V Liso
# ...              ...        ...                 ...                     ...
# 122256         69846 2019-12-25   Salvador Shopping           Short Estampa
# 122257         69846 2019-12-25   Salvador Shopping           Tênis Estampa
# 122258         69850 2019-12-25   Salvador Shopping           Calça Estampa
# 122259         69972 2019-12-26   Salvador Shopping              Terno Liso
# 122260         69972 2019-12-26   Salvador Shopping          Sapato Estampa
#
#         Quantidade  Valor Unitário  Valor Final  Comissão  Imposto   Gerente
# 0                2             180          360     18.00        0  Salvador
# 1                1             368          368     18.40        0  Salvador
# 2                2             116          232     11.60        0  Salvador
# 3                1             363          363     18.15        0  Salvador
# 4                2             118          236     11.80        0  Salvador
# ...            ...             ...          ...       ...      ...       ...
# 122256           2              96          192      9.60        0    Mateus
# 122257           5             256         1280     64.00        0    Mateus
# 122258           4             177          708     35.40        0    Mateus
# 122259           3             720         2160    108.00        0    Mateus
# 122260           5             358         1790     89.50        0    Mateus
#
# [122261 rows x 10 columns]

# %% [markdown]
# ### Como continuar aprendendo?
#
# ### Minicurso Gratuito de Análise de Dados com Python na Descrição
